# %%
print('This is my first Python notebook in Databricks')

# %%
def name():
    first_name = 'Pubudu'
    last_name = 'Piyumal'
    return first_name, last_name
first_name, last_name = name()
print('My name is ', first_name, last_name)

# %%
def age():
    my_age = 28
    return my_age
my_age = age()
print('My age is', my_age, 'years old.')
